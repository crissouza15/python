# %% [markdown]
# <a href="https://colab.research.google.com/github/crissouza15/python/blob/main/palavrasDificeis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# palavras dificeis - saeb ❇ ❤ ❣
#
# ![raposa](data:application/octet-stream;base64,...)

# %% [markdown]
# #enunciado 01:
#
# Imagine que você está desenvolvendo uma seção de comentários em uma
# rede social. Cada comentário terá um contador de curtidas. Analise o código que demonstra a
# implementação deste contador usando HTML e JavaScript
#
# ***Palavras que podem dificultar entendimento da resolução:***
#
# botaoCurtir.addEventListener("click", function() {
#    - Isso significa que você está dizendo ao navegador para "ouvir" (ou escutar) o botão chamado Quando o botão for clicado (evento "click"), o código dentro da função será executado.
#
# numCurtidas = numCurtidas + 1;
# - que deve guardar um número) e somando 1 a ela. Ou seja, você está incrementando a quantidade de curtidas.
#
# contadorCurtidas.textContent = numCurtidas;
# - provavelmente um elemento HTML, como um <span> ou <div>) para mostrar o valor atual da variável numCurtidas. Assim, o usuário vê a quantidade atualizada de curtidas na tela.
#
# #enunciado 02:
# Em um sistema de estacionamento, o valor cobrado depende do número
# de horas que o carro ficou estacionado. A cada hora completa, é cobrado R$ 5,00, e o valor
# total é calculado somente se o tempo for maior que zero. O código a seguir verifica o tempo
# estacionado e retorna o valor a ser pago:
#
# **Palavras que podem dificultar entendimento da resolução:**
#
# dentro do addEventListener.
#
# function calculaEstacionamento(horasTotais) {
#
# if (horasTotais > 0) {
#
# let valorTotal = horasTotais * 5;
#
# return `Total a pagar: R$ ${valorTotal}`;
#
# } else {
#
# return "Nenhum valor a pagar.";
#
# #enunciado 03:
# O código JavaScript implementa um contador de curtidas, mas a lógica de
# atualização está diretamente dentro do addEventListener. Agrupar todas as tarefas necessárias
# em uma função é considerado uma boa prática neste caso. Para isso, a função deve:
#
# ● Receber o número de curtidas atual como parâmetro de entrada.
#
# ● Incrementar esse número em 1.
#
# ● Atualizar o textContent do elemento com o id curtidas.
#
# ● Retornar o novo número de curtidas.
#
# **Palavras que podem dificultar entendimento da resolução:**
#
# ● Incrementar esse número em 1.
#
# ● Atualizar o textContent do elemento com o id curtidas.
#
# ● Retornar o novo número de curtidas.

# %% [markdown]
# **negrito**
